# %%
! pip install pandas psycopg2-binary # or pip install pandas SQLAlchemy
# Out:
# ...
#   Using cached psycopg2_binary-2.9.9-cp311-cp311-macosx_10_9_x86_64.whl.metadata (4.4 kB)
# ...
# Using cached psycopg2_binary-2.9.9-cp311-cp311-macosx_10_9_x86_64.whl (2.8 MB)
# ...

# %%
! pip3 install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.3 MB/s eta 0:00:00:00:0100:01
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.2
#     Uninstalling pip-23.3.2:
#       Successfully uninstalled pip-23.3.2
# ...

# %%
import pandas as pd


# If your JSON data is stored in a dictionary, you can directly pass it to pd.DataFrame() instead of reading from a file.

# Read JSON file into pandas DataFrame
data = pd.read_json('all_holidays_2024.json')
df = pd.DataFrame(data)

# Now you can work with the DataFrame 'df'
print(df.head())  # Display the first few rows of the DataFrame
#reformatted_all_holidays_2024
df.to_csv('reformatted_all_holidays_2024.csv', index=False)
# Out:
#         date              localName              name countryCode  fixed  \
# 0 2024-01-01                Any nou    New Year's Day          AD   True
# 1 2024-01-06                   Reis          Epiphany          AD   True
# 2 2024-02-12               Carnaval          Carnival          AD  False
# 3 2024-03-14  Dia de la Constitució  Constitution Day          AD   True
# 4 2024-03-29         Divendres Sant       Good Friday          AD  False
#
#    global counties  launchYear     types
# 0    True     None         NaN  [Public]
# 1    True     None         NaN  [Public]
# 2    True     None         NaN  [Public]
# 3    True     None         NaN  [Public]
# 4    True     None         NaN  [Public]

# %%
df
# Out:
#            date              localName                name countryCode  fixed  \
# 0    2024-01-01                Any nou      New Year's Day          AD   True
# 1    2024-01-06                   Reis            Epiphany          AD   True
# 2    2024-02-12               Carnaval            Carnival          AD  False
# 3    2024-03-14  Dia de la Constitució    Constitution Day          AD   True
# 4    2024-03-29         Divendres Sant         Good Friday          AD  False
# ...         ...                    ...                 ...         ...    ...
# 1516 2024-08-12            Heroes' Day         Heroes' Day          ZW  False
# 1517 2024-08-13     Defence Forces Day  Defence Forces Day          ZW  False
# 1518 2024-12-22              Unity Day           Unity Day          ZW   True
# 1519 2024-12-25          Christmas Day       Christmas Day          ZW   True
# 1520 2024-12-26             Boxing Day   St. Stephen's Day          ZW   True
#
# ...

# %%
pip install scipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 676.3 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 7.6 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# 'countryCode' column contains the country codes

# Get unique country codes
country_codes = df['countryCode'].unique()

# Print the list of unique country codes
print("List of Unique Country Codes:")
for code in country_codes:
    print(code)
# Out:
# List of Unique Country Codes:
# AD
# AL
# AR
# AT
# AU
# AX
# BA
# BB
# BE
# BG
# BJ
# BO
# BR
# BS
# BW
# BY
# BZ
# CA
# CH
# CL
# CN
# CO
# CR
# CU
# CY
# CZ
# DE
# DK
# DO
# EC
# EE
# EG
# ES
# FI
# FO
# FR
# GA
# GB
# GD
# GG
# GI
# GL
# GM
# GR
# GT
# GY
# HN
# HR
# HT
# HU
# ID
# IE
# IM
# IS
# IT
# JE
# JM
# JP
# KR
# LI
# LS
# LT
# LU
# LV
# MA
# MC
# MD
# ME
# MG
# MK
# MN
# MS
# MT
# MX
# MZ
# NA
# NE
# NG
# NI
# NL
# NO
# NZ
# PA
# PE
# PG
# PL
# PR
# PT
# PY
# RO
# RS
# RU
# SE
# SG
# SI
# SJ
# SK
# SM
# SR
# SV
# TN
# TR
# UA
# US
# UY
# VA
# VE
# VN
# ZA
# ZW

# %%
from scipy.stats import f_oneway

# 'fixed' column contains the number of fixed holidays for each country

# Perform ANOVA test
f_statistic, p_value = f_oneway(df[df['countryCode'] == 'US']['fixed'],
                                 df[df['countryCode'] == 'CA']['fixed'],
                                 df[df['countryCode'] == 'MX']['fixed'])

# Print results
print("F-statistic:", f_statistic)
print("p-value:", p_value)

# Interpret results
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in the average number of fixed holidays between countries.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference.")
# Out:
# F-statistic: 3.806991733221242
# p-value: 0.029051795212931324
# Reject the null hypothesis. There is a significant difference in the average number of fixed holidays between countries.

# %%
from scipy.stats import f_oneway

# 'fixed' column contains the number of fixed holidays for each country
#Regression Analysis...

# Perform ANOVA test
f_statistic, p_value = f_oneway(df[df['countryCode'] == 'AD']['fixed'],
                                 df[df['countryCode'] == 'AL']['fixed'],
                                 df[df['countryCode'] == 'AR']['fixed'],
                                 df[df['countryCode'] == 'AT']['fixed'],
                                 df[df['countryCode'] == 'AU']['fixed'],
                                 df[df['countryCode'] == 'AX']['fixed'],
                                 df[df['countryCode'] == 'BA']['fixed'],
                                 df[df['countryCode'] == 'BB']['fixed'],
                                 df[df['countryCode'] == 'BE']['fixed'],
                                 df[df['countryCode'] == 'BG']['fixed'],
                                 df[df['countryCode'] == 'BJ']['fixed'],
                                 df[df['countryCode'] == 'BO']['fixed'],
                                 df[df['countryCode'] == 'BR']['fixed'],
                                 df[df['countryCode'] == 'BS']['fixed'],
                                 df[df['countryCode'] == 'BW']['fixed'],
                                 df[df['countryCode'] == 'BY']['fixed'],
                                 df[df['countryCode'] == 'BZ']['fixed'],
                                 df[df['countryCode'] == 'CA']['fixed'],
                                 df[df['countryCode'] == 'CH']['fixed'],
                                 df[df['countryCode'] == 'CL']['fixed'],
                                 df[df['countryCode'] == 'CN']['fixed'],
                                 df[df['countryCode'] == 'CO']['fixed'],
                                 df[df['countryCode'] == 'CR']['fixed'],
                                 df[df['countryCode'] == 'CU']['fixed'],
                                 df[df['countryCode'] == 'CY']['fixed'],
                                 df[df['countryCode'] == 'CZ']['fixed'],
                                 df[df['countryCode'] == 'DE']['fixed'],
                                 df[df['countryCode'] == 'DK']['fixed'],
                                 df[df['countryCode'] == 'DO']['fixed'],
                                 df[df['countryCode'] == 'EC']['fixed'],
                                 df[df['countryCode'] == 'EE']['fixed'],
                                 df[df['countryCode'] == 'EG']['fixed'],
                                 df[df['countryCode'] == 'ES']['fixed'],
                                 df[df['countryCode'] == 'FI']['fixed'],
                                 df[df['countryCode'] == 'FO']['fixed'],
                                 df[df['countryCode'] == 'FR']['fixed'],
                                 df[df['countryCode'] == 'GA']['fixed'],
                                 df[df['countryCode'] == 'GB']['fixed'],
                                 df[df['countryCode'] == 'GD']['fixed'],
                                 df[df['countryCode'] == 'GG']['fixed'],
                                 df[df['countryCode'] == 'GI']['fixed'],
                                 df[df['countryCode'] == 'GL']['fixed'],
                                 df[df['countryCode'] == 'GM']['fixed'],
                                 df[df['countryCode'] == 'GR']['fixed'],
                                 df[df['countryCode'] == 'GT']['fixed'],
                                 df[df['countryCode'] == 'GY']['fixed'],
                                 df[df['countryCode'] == 'HN']['fixed'],
                                 df[df['countryCode'] == 'HR']['fixed'],
                                 df[df['countryCode'] == 'HT']['fixed'],
                                 df[df['countryCode'] == 'HU']['fixed'],
                                 df[df['countryCode'] == 'ID']['fixed'],
                                 df[df['countryCode'] == 'IE']['fixed'],
                                 df[df['countryCode'] == 'IM']['fixed'],
                                 df[df['countryCode'] == 'IS']['fixed'],
                                 df[df['countryCode'] == 'IT']['fixed'],
                                 df[df['countryCode'] == 'JE']['fixed'],
                                 df[df['countryCode'] == 'JM']['fixed'],
                                 df[df['countryCode'] == 'JP']['fixed'],
                                 df[df['countryCode'] == 'KR']['fixed'],
                                 df[df['countryCode'] == 'LI']['fixed'],
                                 df[df['countryCode'] == 'LS']['fixed'],
                                 df[df['countryCode'] == 'LT']['fixed'],
                                 df[df['countryCode'] == 'LU']['fixed'],
                                 df[df['countryCode'] == 'LV']['fixed'],
                                 df[df['countryCode'] == 'MA']['fixed'],
                                 df[df['countryCode'] == 'MC']['fixed'],
                                 df[df['countryCode'] == 'MD']['fixed'],
                                 df[df['countryCode'] == 'ME']['fixed'],
                                 df[df['countryCode'] == 'MG']['fixed'],
                                 df[df['countryCode'] == 'MK']['fixed'],
                                 df[df['countryCode'] == 'MN']['fixed'],
                                 df[df['countryCode'] == 'MS']['fixed'],
                                 df[df['countryCode'] == 'MT']['fixed'],
                                 df[df['countryCode'] == 'MX']['fixed'],
                                 df[df['countryCode'] == 'MZ']['fixed'],
                                 df[df['countryCode'] == 'NA']['fixed'],
                                 df[df['countryCode'] == 'NE']['fixed'],
                                 df[df['countryCode'] == 'NG']['fixed'],
                                 df[df['countryCode'] == 'NI']['fixed'],
                                 df[df['countryCode'] == 'NL']['fixed'],
                                 df[df['countryCode'] == 'NO']['fixed'],
                                 df[df['countryCode'] == 'NZ']['fixed'],
                                 df[df['countryCode'] == 'PA']['fixed'],
                                 df[df['countryCode'] == 'PE']['fixed'],
                                 df[df['countryCode'] == 'PG']['fixed'],
                                 df[df['countryCode'] == 'PL']['fixed'],
                                 df[df['countryCode'] == 'PR']['fixed'],
                                 df[df['countryCode'] == 'PT']['fixed'],
                                 df[df['countryCode'] == 'PY']['fixed'],
                                 df[df['countryCode'] == 'RO']['fixed'],
                                 df[df['countryCode'] == 'RS']['fixed'],
                                 df[df['countryCode'] == 'RU']['fixed'],
                                 df[df['countryCode'] == 'SE']['fixed'],
                                 df[df['countryCode'] == 'SG']['fixed'],
                                 df[df['countryCode'] == 'SI']['fixed'],
                                 df[df['countryCode'] == 'SJ']['fixed'],
                                 df[df['countryCode'] == 'SK']['fixed'],
                                 df[df['countryCode'] == 'SM']['fixed'],
                                 df[df['countryCode'] == 'SR']['fixed'],
                                 df[df['countryCode'] == 'SV']['fixed'],
                                 df[df['countryCode'] == 'TN']['fixed'],
                                 df[df['countryCode'] == 'TR']['fixed'],
                                 df[df['countryCode'] == 'UA']['fixed'],
                                 df[df['countryCode'] == 'US']['fixed'],
                                 df[df['countryCode'] == 'UY']['fixed'],
                                 df[df['countryCode'] == 'VA']['fixed'],
                                 df[df['countryCode'] == 'VE']['fixed'],
                                 df[df['countryCode'] == 'VN']['fixed'],
                                 df[df['countryCode'] == 'ZA']['fixed'],
                                 df[df['countryCode'] == 'ZW']['fixed'])

# Print results
print("F-statistic:", f_statistic)
print("p-value:", p_value)

# Interpret results
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in the average number of fixed holidays between countries.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference.")
# Out:
# F-statistic: 4.917863280287758
# p-value: 1.725069229210718e-46
# Reject the null hypothesis. There is a significant difference in the average number of fixed holidays between countries.

# %%
# Flatten lists in 'types' column
df['types'] = df['types'].apply(lambda x: ', '.join(x) if isinstance(x, list) else x)

# Perform chi-square test
contingency_table = pd.crosstab(df['types'], df['countryCode'])
chi2_statistic, p_value, _, _ = chi2_contingency(contingency_table)

# Print results
print("Chi-square statistic:", chi2_statistic)
print("p-value:", p_value)

# Interpret results
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant association between types of holidays and countries.")
else:
    print("Fail to reject the null hypothesis. There is no significant association.")
# Out:
# Chi-square statistic: 1965.3425532967663
# p-value: 3.5185817497425714e-131
# Reject the null hypothesis. There is a significant association between types of holidays and countries.
